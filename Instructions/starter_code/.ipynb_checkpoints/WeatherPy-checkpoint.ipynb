# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import random
import time
from scipy import stats as st

from citipy import citipy
from api_keys import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
#Create lists for holding pulled data
cities = []
lat_longs = []

#Create random latitude and longitudes for finding cities
lats=np.random.uniform(-90.0,90.0, size=1500)
longs=np.random.uniform(-180.0,180.0, size=1500)
lat_longs = zip(lats, longs) 

#Find the nearest city by latitude and longitude
for lat_lng in lat_longs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
        
        #Eliminate running into duplicate cities
        if city not in cities:
            cities.append(city)

#Confirm city numbers are 500+
cities_count = len(cities)
print(cities_count)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create lists for API call data
city_name = []
cloudiness = []
humidity = []
temp = []
wind_speed = []
lat = []
long = []

call_count = 1

#Print Statement
print(f"Begin Data Retrieval")
print(f"--------------------------------------------------")

#Set Loop
for city in cities:
    
    print(f"Retrieving Data for city {call_count}: {city}")
    try:
        response = requests.get(url + city.replace(" ","&")).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        humidity.append(response["main"]["humidity"])
        temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["long"])
        
        call_count += 1
        
    except:
        print("No Matching Data")
# Out:
# Begin Data Retrieval
# --------------------------------------------------
# Retrieving Data for city 1: bredasdorp
# No Matching Data
# Retrieving Data for city 1: rikitea
# No Matching Data
# Retrieving Data for city 1: erenhot
# No Matching Data
# Retrieving Data for city 1: kapaa
# No Matching Data
# Retrieving Data for city 1: san ramon
# No Matching Data
# Retrieving Data for city 1: hermanus
# No Matching Data
# Retrieving Data for city 1: leninskiy
# No Matching Data
# Retrieving Data for city 1: sisimiut
# No Matching Data
# Retrieving Data for city 1: broken hill
# No Matching Data
# Retrieving Data for city 1: petropavlovsk-kamchatskiy
# No Matching Data
# Retrieving Data for city 1: vaini
# No Matching Data
# Retrieving Data for city 1: alofi
# No Matching Data
# Retrieving Data for city 1: new norfolk
# No Matching Data
# Retrieving Data for city 1: bluff
# No Matching Data
# Retrieving Data for city 1: pisco
# No Matching Data
# Retrieving Data for city 1: wewak
# No Matching Data
# Retrieving Data for city 1: fabriano
# No Matching Data
# Retrieving Data for city 1: omsukchan
# No Matching Data
# Retrieving Data for city 1: albany
# No Matching Data
# Retrieving Data for city 1: mrirt
# No Matching Data
# Retrieving Data for city 1: jamestown
# No Matching Data
# Retrieving Data for city 1: aklavik
# No Matching Data
# Retrieving Data for city 1: mataura
# No Matching Data
# Retrieving Data for city 1: cape town
# No Matching Data
# Retrieving Data for city 1: giyani
# No Matching Data
# Retrieving Data for city 1: sambava
# No Matching Data
# Retrieving Data for city 1: aswan
# No Matching Data
# Retrieving Data for city 1: avera
# No Matching Data
# Retrieving Data for city 1: hobart
# No Matching Data
# Retrieving Data for city 1: punta arenas
# No Matching Data
# Retrieving Data for city 1: bowen
# No Matching Data
# Retrieving Data for city 1: port alfred
# No Matching Data
# Retrieving Data for city 1: pierre
# No Matching Data
# Retrieving Data for city 1: saskylakh
# No Matching Data
# Retrieving Data for city 1: riyadh
# No Matching Data
# Retrieving Data for city 1: klaksvik
# No Matching Data
# Retrieving Data for city 1: mys shmidta
# No Matching Data
# Retrieving Data for city 1: hambantota
# No Matching Data
# Retrieving Data for city 1: aripuana
# No Matching Data
# Retrieving Data for city 1: port elizabeth
# No Matching Data
# Retrieving Data for city 1: belushya guba
# No Matching Data
# Retrieving Data for city 1: severomuysk
# No Matching Data
# Retrieving Data for city 1: avarua
# No Matching Data
# Retrieving Data for city 1: kamenskoye
# No Matching Data
# Retrieving Data for city 1: kalmunai
# No Matching Data
# Retrieving Data for city 1: salinopolis
# No Matching Data
# Retrieving Data for city 1: shaoyang
# No Matching Data
# Retrieving Data for city 1: paradwip
# No Matching Data
# Retrieving Data for city 1: tual
# No Matching Data
# Retrieving Data for city 1: lebu
# No Matching Data
# Retrieving Data for city 1: mar del plata
# No Matching Data
# Retrieving Data for city 1: clyde river
# No Matching Data
# Retrieving Data for city 1: taltal
# No Matching Data
# Retrieving Data for city 1: tezu
# No Matching Data
# Retrieving Data for city 1: auki
# No Matching Data
# Retrieving Data for city 1: saint george
# No Matching Data
# Retrieving Data for city 1: norman wells
# No Matching Data
# Retrieving Data for city 1: sentyabrskiy
# No Matching Data
# Retrieving Data for city 1: severo-kurilsk
# No Matching Data
# Retrieving Data for city 1: addis zemen
# No Matching Data
# Retrieving Data for city 1: sola
# No Matching Data
# Retrieving Data for city 1: jalu
# No Matching Data
# Retrieving Data for city 1: te anau
# No Matching Data
# Retrieving Data for city 1: thompson
# No Matching Data
# Retrieving Data for city 1: taolanaro
# No Matching Data
# Retrieving Data for city 1: marrakesh
# No Matching Data
# Retrieving Data for city 1: leningradskiy
# No Matching Data
# Retrieving Data for city 1: iqaluit
# No Matching Data
# Retrieving Data for city 1: cortez
# No Matching Data
# Retrieving Data for city 1: narsaq
# No Matching Data
# Retrieving Data for city 1: salalah
# No Matching Data
# Retrieving Data for city 1: ushuaia
# No Matching Data
# Retrieving Data for city 1: houston
# No Matching Data
# Retrieving Data for city 1: hilo
# No Matching Data
# Retrieving Data for city 1: tawkar
# No Matching Data
# Retrieving Data for city 1: bridlington
# No Matching Data
# Retrieving Data for city 1: luanda
# No Matching Data
# Retrieving Data for city 1: komsomolskiy
# No Matching Data
# Retrieving Data for city 1: tucupita
# No Matching Data
# Retrieving Data for city 1: tuatapere
# No Matching Data
# Retrieving Data for city 1: chuy
# No Matching Data
# Retrieving Data for city 1: trabzon
# No Matching Data
# Retrieving Data for city 1: puerto ayora
# No Matching Data
# Retrieving Data for city 1: bentiu
# No Matching Data
# Retrieving Data for city 1: qaanaaq
# No Matching Data
# Retrieving Data for city 1: gogrial
# No Matching Data
# Retrieving Data for city 1: acari
# No Matching Data
# Retrieving Data for city 1: alta floresta
# No Matching Data
# Retrieving Data for city 1: buala
# No Matching Data
# Retrieving Data for city 1: roebourne
# No Matching Data
# Retrieving Data for city 1: tuktoyaktuk
# No Matching Data
# Retrieving Data for city 1: goderich
# No Matching Data
# Retrieving Data for city 1: meyungs
# No Matching Data
# Retrieving Data for city 1: benguela
# No Matching Data
# Retrieving Data for city 1: llangefni
# No Matching Data
# Retrieving Data for city 1: isangel
# No Matching Data
# Retrieving Data for city 1: nakamura
# No Matching Data
# Retrieving Data for city 1: atuona
# No Matching Data
# Retrieving Data for city 1: tarare
# No Matching Data
# Retrieving Data for city 1: nouadhibou
# No Matching Data
# Retrieving Data for city 1: maragogi
# No Matching Data
# Retrieving Data for city 1: laguna
# No Matching Data
# Retrieving Data for city 1: biak
# No Matching Data
# Retrieving Data for city 1: mirpur sakro
# No Matching Data
# Retrieving Data for city 1: karamea
# No Matching Data
# Retrieving Data for city 1: hit
# No Matching Data
# Retrieving Data for city 1: matara
# No Matching Data
# Retrieving Data for city 1: shaowu
# No Matching Data
# Retrieving Data for city 1: mocambique
# No Matching Data
# Retrieving Data for city 1: general pico
# No Matching Data
# Retrieving Data for city 1: arraial do cabo
# No Matching Data
# Retrieving Data for city 1: strezhevoy
# No Matching Data
# Retrieving Data for city 1: port moresby
# No Matching Data
# Retrieving Data for city 1: khandyga
# No Matching Data
# Retrieving Data for city 1: rezh
# No Matching Data
# Retrieving Data for city 1: amderma
# No Matching Data
# Retrieving Data for city 1: tasiilaq
# No Matching Data
# Retrieving Data for city 1: victoria
# No Matching Data
# Retrieving Data for city 1: xining
# No Matching Data
# Retrieving Data for city 1: tumannyy
# No Matching Data
# Retrieving Data for city 1: turbat
# No Matching Data
# Retrieving Data for city 1: ancud
# No Matching Data
# Retrieving Data for city 1: asau
# No Matching Data
# Retrieving Data for city 1: katsuura
# No Matching Data
# Retrieving Data for city 1: lorengau
# No Matching Data
# Retrieving Data for city 1: talnakh
# No Matching Data
# Retrieving Data for city 1: busselton
# No Matching Data
# Retrieving Data for city 1: brandfort
# No Matching Data
# Retrieving Data for city 1: surt
# No Matching Data
# Retrieving Data for city 1: maamba
# No Matching Data
# Retrieving Data for city 1: cockburn town
# No Matching Data
# Retrieving Data for city 1: constitucion
# No Matching Data
# Retrieving Data for city 1: lintangan
# No Matching Data
# Retrieving Data for city 1: hithadhoo
# No Matching Data
# Retrieving Data for city 1: saleaula
# No Matching Data
# Retrieving Data for city 1: bubaque
# No Matching Data
# Retrieving Data for city 1: ariquemes
# No Matching Data
# Retrieving Data for city 1: vestmannaeyjar
# No Matching Data
# Retrieving Data for city 1: mount gambier
# No Matching Data
# Retrieving Data for city 1: paamiut
# No Matching Data
# Retrieving Data for city 1: karratha
# No Matching Data
# Retrieving Data for city 1: sitka
# No Matching Data
# Retrieving Data for city 1: yulara
# No Matching Data
# Retrieving Data for city 1: helena
# No Matching Data
# Retrieving Data for city 1: longyearbyen
# No Matching Data
# Retrieving Data for city 1: ossora
# No Matching Data
# Retrieving Data for city 1: illoqqortoormiut
# No Matching Data
# Retrieving Data for city 1: calabozo
# No Matching Data
# Retrieving Data for city 1: pakhtakoron
# No Matching Data
# Retrieving Data for city 1: monticello
# No Matching Data
# Retrieving Data for city 1: cherskiy
# No Matching Data
# Retrieving Data for city 1: kuryk
# No Matching Data
# Retrieving Data for city 1: nemuro
# No Matching Data
# Retrieving Data for city 1: pemangkat
# No Matching Data
# Retrieving Data for city 1: trinidad
# No Matching Data
# Retrieving Data for city 1: soe
# No Matching Data
# Retrieving Data for city 1: novosergiyevka
# No Matching Data
# Retrieving Data for city 1: otane
# No Matching Data
# Retrieving Data for city 1: westport
# No Matching Data
# Retrieving Data for city 1: vestmanna
# No Matching Data
# Retrieving Data for city 1: peleduy
# No Matching Data
# Retrieving Data for city 1: mao
# No Matching Data
# Retrieving Data for city 1: coquimbo
# No Matching Data
# Retrieving Data for city 1: sibolga
# No Matching Data
# Retrieving Data for city 1: torbay
# No Matching Data
# Retrieving Data for city 1: georgetown
# No Matching Data
# Retrieving Data for city 1: dikson
# No Matching Data
# Retrieving Data for city 1: smithers
# No Matching Data
# Retrieving Data for city 1: fukue
# No Matching Data
# Retrieving Data for city 1: nikolskoye
# No Matching Data
# Retrieving Data for city 1: airai
# No Matching Data
# Retrieving Data for city 1: sioux lookout
# No Matching Data
# Retrieving Data for city 1: saint-joseph
# No Matching Data
# Retrieving Data for city 1: kargopol
# No Matching Data
# Retrieving Data for city 1: kahului
# No Matching Data
# Retrieving Data for city 1: saint-philippe
# No Matching Data
# Retrieving Data for city 1: paramonga
# No Matching Data
# Retrieving Data for city 1: hami
# No Matching Data
# Retrieving Data for city 1: kavaratti
# No Matching Data
# Retrieving Data for city 1: pevek
# No Matching Data
# Retrieving Data for city 1: tautira
# No Matching Data
# Retrieving Data for city 1: nadym
# No Matching Data
# Retrieving Data for city 1: kaeo
# No Matching Data
# Retrieving Data for city 1: kozmodemyansk
# No Matching Data
# Retrieving Data for city 1: petukhovo
# No Matching Data
# Retrieving Data for city 1: alugan
# No Matching Data
# Retrieving Data for city 1: lagoa
# No Matching Data
# Retrieving Data for city 1: castro
# No Matching Data
# Retrieving Data for city 1: hualmay
# No Matching Data
# Retrieving Data for city 1: yar-sale
# No Matching Data
# Retrieving Data for city 1: manzhouli
# No Matching Data
# Retrieving Data for city 1: makung
# No Matching Data
# Retrieving Data for city 1: grand river south east
# No Matching Data
# Retrieving Data for city 1: erzin
# No Matching Data
# Retrieving Data for city 1: nagutskoye
# No Matching Data
# Retrieving Data for city 1: kefamenanu
# No Matching Data
# Retrieving Data for city 1: husavik
# No Matching Data
# Retrieving Data for city 1: valparaiso
# No Matching Data
# Retrieving Data for city 1: shingu
# No Matching Data
# Retrieving Data for city 1: meadow lake
# No Matching Data
# Retrieving Data for city 1: shellbrook
# No Matching Data
# Retrieving Data for city 1: zheshart
# No Matching Data
# Retrieving Data for city 1: pudozh
# No Matching Data
# Retrieving Data for city 1: deputatskiy
# No Matching Data
# Retrieving Data for city 1: resplendor
# No Matching Data
# Retrieving Data for city 1: biscarrosse
# No Matching Data
# Retrieving Data for city 1: roma
# No Matching Data
# Retrieving Data for city 1: fort nelson
# No Matching Data
# Retrieving Data for city 1: tiksi
# No Matching Data
# Retrieving Data for city 1: faanui
# No Matching Data
# Retrieving Data for city 1: butaritari
# No Matching Data
# Retrieving Data for city 1: kharp
# No Matching Data
# Retrieving Data for city 1: kamaishi
# No Matching Data
# Retrieving Data for city 1: daru
# No Matching Data
# Retrieving Data for city 1: xai-xai
# No Matching Data
# Retrieving Data for city 1: waharoa
# No Matching Data
# Retrieving Data for city 1: meulaboh
# No Matching Data
# Retrieving Data for city 1: tomari
# No Matching Data
# Retrieving Data for city 1: beringovskiy
# No Matching Data
# Retrieving Data for city 1: kendari
# No Matching Data
# Retrieving Data for city 1: upington
# No Matching Data
# Retrieving Data for city 1: japura
# No Matching Data
# Retrieving Data for city 1: pangody
# No Matching Data
# Retrieving Data for city 1: gizo
# No Matching Data
# Retrieving Data for city 1: catuday
# No Matching Data
# Retrieving Data for city 1: namibe
# No Matching Data
# Retrieving Data for city 1: olafsvik
# No Matching Data
# Retrieving Data for city 1: mahebourg
# No Matching Data
# Retrieving Data for city 1: souillac
# No Matching Data
# Retrieving Data for city 1: vila velha
# No Matching Data
# Retrieving Data for city 1: svetlogorsk
# No Matching Data
# Retrieving Data for city 1: nuuk
# No Matching Data
# Retrieving Data for city 1: khatanga
# No Matching Data
# Retrieving Data for city 1: camopi
# No Matching Data
# Retrieving Data for city 1: margate
# No Matching Data
# Retrieving Data for city 1: nara
# No Matching Data
# Retrieving Data for city 1: aksha
# No Matching Data
# Retrieving Data for city 1: east london
# No Matching Data
# Retrieving Data for city 1: aleksandrow kujawski
# No Matching Data
# Retrieving Data for city 1: mogadishu
# No Matching Data
# Retrieving Data for city 1: manohar thana
# No Matching Data
# Retrieving Data for city 1: hof
# No Matching Data
# Retrieving Data for city 1: salym
# No Matching Data
# Retrieving Data for city 1: jimma
# No Matching Data
# Retrieving Data for city 1: bakchar
# No Matching Data
# Retrieving Data for city 1: port lincoln
# No Matching Data
# Retrieving Data for city 1: rawson
# No Matching Data
# Retrieving Data for city 1: codrington
# No Matching Data
# Retrieving Data for city 1: nantucket
# No Matching Data
# Retrieving Data for city 1: touros
# No Matching Data
# Retrieving Data for city 1: baillif
# No Matching Data
# Retrieving Data for city 1: vaitupu
# No Matching Data
# Retrieving Data for city 1: melfi
# No Matching Data
# Retrieving Data for city 1: kyaikkami
# No Matching Data
# Retrieving Data for city 1: brae
# No Matching Data
# Retrieving Data for city 1: kaitangata
# No Matching Data
# Retrieving Data for city 1: rio grande
# No Matching Data
# Retrieving Data for city 1: sale
# No Matching Data
# Retrieving Data for city 1: san felipe
# No Matching Data
# Retrieving Data for city 1: nam som
# No Matching Data
# Retrieving Data for city 1: norfolk
# No Matching Data
# Retrieving Data for city 1: altamont
# No Matching Data
# Retrieving Data for city 1: yellowknife
# No Matching Data
# Retrieving Data for city 1: madimba
# No Matching Data
# Retrieving Data for city 1: bara
# No Matching Data
# Retrieving Data for city 1: barrow
# No Matching Data
# Retrieving Data for city 1: pital
# No Matching Data
# Retrieving Data for city 1: kamenka
# No Matching Data
# Retrieving Data for city 1: kiama
# No Matching Data
# Retrieving Data for city 1: merauke
# No Matching Data
# Retrieving Data for city 1: kudahuvadhoo
# No Matching Data
# Retrieving Data for city 1: north bend
# No Matching Data
# Retrieving Data for city 1: anadyr
# No Matching Data
# Retrieving Data for city 1: kodiak
# No Matching Data
# Retrieving Data for city 1: bambous virieux
# No Matching Data
# Retrieving Data for city 1: monrovia
# No Matching Data
# Retrieving Data for city 1: de-kastri
# No Matching Data
# Retrieving Data for city 1: parras
# No Matching Data
# Retrieving Data for city 1: port hawkesbury
# No Matching Data
# Retrieving Data for city 1: cidreira
# No Matching Data
# Retrieving Data for city 1: fayaoue
# No Matching Data
# Retrieving Data for city 1: santa isabel do rio negro
# No Matching Data
# Retrieving Data for city 1: taicheng
# No Matching Data
# Retrieving Data for city 1: temryuk
# No Matching Data
# Retrieving Data for city 1: tazovskiy
# No Matching Data
# Retrieving Data for city 1: juneau
# No Matching Data
# Retrieving Data for city 1: verkhozim
# No Matching Data
# Retrieving Data for city 1: bethel
# No Matching Data
# Retrieving Data for city 1: dargaville
# No Matching Data
# Retrieving Data for city 1: ribeira grande
# No Matching Data
# Retrieving Data for city 1: champua
# No Matching Data
# Retrieving Data for city 1: padang
# No Matching Data
# Retrieving Data for city 1: sinnamary
# No Matching Data
# Retrieving Data for city 1: newark
# No Matching Data
# Retrieving Data for city 1: nizhneyansk
# No Matching Data
# Retrieving Data for city 1: bargal
# No Matching Data
# Retrieving Data for city 1: zarand
# No Matching Data
# Retrieving Data for city 1: san quintin
# No Matching Data
# Retrieving Data for city 1: snezhnogorsk
# No Matching Data
# Retrieving Data for city 1: necochea
# No Matching Data
# Retrieving Data for city 1: suoyarvi
# No Matching Data
# Retrieving Data for city 1: burica
# No Matching Data
# Retrieving Data for city 1: mbarara
# No Matching Data
# Retrieving Data for city 1: kostalexis
# No Matching Data
# Retrieving Data for city 1: huilong
# No Matching Data
# Retrieving Data for city 1: cozumel
# No Matching Data
# Retrieving Data for city 1: san martin
# No Matching Data
# Retrieving Data for city 1: okhotsk
# No Matching Data
# Retrieving Data for city 1: berlevag
# No Matching Data
# Retrieving Data for city 1: sorland
# No Matching Data
# Retrieving Data for city 1: santa lucia
# No Matching Data
# Retrieving Data for city 1: tubuala
# No Matching Data
# Retrieving Data for city 1: bengkulu
# No Matching Data
# Retrieving Data for city 1: upernavik
# No Matching Data
# Retrieving Data for city 1: baoding
# No Matching Data
# Retrieving Data for city 1: lykhivka
# No Matching Data
# Retrieving Data for city 1: katangli
# No Matching Data
# Retrieving Data for city 1: harrison
# No Matching Data
# Retrieving Data for city 1: seoul
# No Matching Data
# Retrieving Data for city 1: honiara
# No Matching Data
# Retrieving Data for city 1: ahipara
# No Matching Data
# Retrieving Data for city 1: hirado
# No Matching Data
# Retrieving Data for city 1: lensk
# No Matching Data
# Retrieving Data for city 1: buraydah
# No Matching Data
# Retrieving Data for city 1: camana
# No Matching Data
# Retrieving Data for city 1: bilibino
# No Matching Data
# Retrieving Data for city 1: ponta do sol
# No Matching Data
# Retrieving Data for city 1: chokurdakh
# No Matching Data
# Retrieving Data for city 1: ornskoldsvik
# No Matching Data
# Retrieving Data for city 1: zhigansk
# No Matching Data
# Retrieving Data for city 1: broome
# No Matching Data
# Retrieving Data for city 1: carutapera
# No Matching Data
# Retrieving Data for city 1: usinsk
# No Matching Data
# Retrieving Data for city 1: pangai
# No Matching Data
# Retrieving Data for city 1: nanga eboko
# No Matching Data
# Retrieving Data for city 1: grindavik
# No Matching Data
# Retrieving Data for city 1: caravelas
# No Matching Data
# Retrieving Data for city 1: kavieng
# No Matching Data
# Retrieving Data for city 1: palana
# No Matching Data
# Retrieving Data for city 1: barentsburg
# No Matching Data
# Retrieving Data for city 1: palmeiras de goias
# No Matching Data
# Retrieving Data for city 1: svetlaya
# No Matching Data
# Retrieving Data for city 1: honningsvag
# No Matching Data
# Retrieving Data for city 1: pasighat
# No Matching Data
# Retrieving Data for city 1: saint-augustin
# No Matching Data
# Retrieving Data for city 1: kirkuk
# No Matching Data
# Retrieving Data for city 1: port macquarie
# No Matching Data
# Retrieving Data for city 1: amantea
# No Matching Data
# Retrieving Data for city 1: hamilton
# No Matching Data
# Retrieving Data for city 1: ixtapa
# No Matching Data
# Retrieving Data for city 1: rancho palos verdes
# No Matching Data
# Retrieving Data for city 1: cabo san lucas
# No Matching Data
# Retrieving Data for city 1: grand centre
# No Matching Data
# Retrieving Data for city 1: rodrigues alves
# No Matching Data
# Retrieving Data for city 1: lodhikheda
# No Matching Data
# Retrieving Data for city 1: samusu
# No Matching Data
# Retrieving Data for city 1: traverse city
# No Matching Data
# Retrieving Data for city 1: lappeenranta
# No Matching Data
# Retrieving Data for city 1: saldanha
# No Matching Data
# Retrieving Data for city 1: kruisfontein
# No Matching Data
# Retrieving Data for city 1: tsihombe
# No Matching Data
# Retrieving Data for city 1: hofn
# No Matching Data
# Retrieving Data for city 1: araouane
# No Matching Data
# Retrieving Data for city 1: dudinka
# No Matching Data
# Retrieving Data for city 1: skoczow
# No Matching Data
# Retrieving Data for city 1: auburndale
# No Matching Data
# Retrieving Data for city 1: dickinson
# No Matching Data
# Retrieving Data for city 1: san francisco
# No Matching Data
# Retrieving Data for city 1: boca do acre
# No Matching Data
# Retrieving Data for city 1: richards bay
# No Matching Data
# Retrieving Data for city 1: nelson bay
# No Matching Data
# Retrieving Data for city 1: gostyn
# No Matching Data
# Retrieving Data for city 1: hartselle
# No Matching Data
# Retrieving Data for city 1: dalvik
# No Matching Data
# Retrieving Data for city 1: katiola
# No Matching Data
# Retrieving Data for city 1: muzhi
# No Matching Data
# Retrieving Data for city 1: lichinga
# No Matching Data
# Retrieving Data for city 1: tumpat
# No Matching Data
# Retrieving Data for city 1: shu
# No Matching Data
# Retrieving Data for city 1: khandbari
# No Matching Data
# Retrieving Data for city 1: playas
# No Matching Data
# Retrieving Data for city 1: ngukurr
# No Matching Data
# Retrieving Data for city 1: bilma
# No Matching Data
# Retrieving Data for city 1: alvdal
# No Matching Data
# Retrieving Data for city 1: moundou
# No Matching Data
# Retrieving Data for city 1: horsham
# No Matching Data
# Retrieving Data for city 1: gashua
# No Matching Data
# Retrieving Data for city 1: chimbote
# No Matching Data
# Retrieving Data for city 1: karatau
# No Matching Data
# Retrieving Data for city 1: pemba
# No Matching Data
# Retrieving Data for city 1: port hedland
# No Matching Data
# Retrieving Data for city 1: hobyo
# No Matching Data
# Retrieving Data for city 1: along
# No Matching Data
# Retrieving Data for city 1: carnarvon
# No Matching Data
# Retrieving Data for city 1: cloquet
# No Matching Data
# Retrieving Data for city 1: port blair
# No Matching Data
# Retrieving Data for city 1: mount isa
# No Matching Data
# Retrieving Data for city 1: dwarka
# No Matching Data
# Retrieving Data for city 1: lulea
# No Matching Data
# Retrieving Data for city 1: kirishi
# No Matching Data
# Retrieving Data for city 1: kouango
# No Matching Data
# Retrieving Data for city 1: hovd
# No Matching Data
# Retrieving Data for city 1: rorvik
# No Matching Data
# Retrieving Data for city 1: chumikan
# No Matching Data
# Retrieving Data for city 1: tabou
# No Matching Data
# Retrieving Data for city 1: chernaya kholunitsa
# No Matching Data
# Retrieving Data for city 1: nhulunbuy
# No Matching Data
# Retrieving Data for city 1: wonthaggi
# No Matching Data
# Retrieving Data for city 1: saint anthony
# No Matching Data
# Retrieving Data for city 1: indramayu
# No Matching Data
# Retrieving Data for city 1: umzimvubu
# No Matching Data
# Retrieving Data for city 1: morondava
# No Matching Data
# Retrieving Data for city 1: ludvika
# No Matching Data
# Retrieving Data for city 1: ballangen
# No Matching Data
# Retrieving Data for city 1: attawapiskat
# No Matching Data
# Retrieving Data for city 1: lethem
# No Matching Data
# Retrieving Data for city 1: anakapalle
# No Matching Data
# Retrieving Data for city 1: ostrovnoy
# No Matching Data
# Retrieving Data for city 1: sechura
# No Matching Data
# Retrieving Data for city 1: rocha
# No Matching Data
# Retrieving Data for city 1: weihe
# No Matching Data
# Retrieving Data for city 1: maracaju

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#weather_data_df.to_csv("Output/weather_data.csv",encoding="utf-8", index=False, header=True)

# weather_data_df = pd.DataFrame({
#     "City":city_name,
#     "Cloudiness (%)":cloudiness,
#     "Humidity (%)":humidity,
#     "Temperature (F)":temp,
#     "Wind Speed (mph)":wind_speed,
#     "Latitude":lat,
#     "Longitude":long
# })
# weather_data_df.head()

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# print(weather_data_df["Humidity (%)"].max())
# print(weather_data_df.count())

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# plt.scatter(weather_data_df["Lat"], weather_data_df["temp"], marker="o", s=12)
# plt.title("City Latitude Vs. Temperature")
# plt.xlabel("Latitude")
# plt.ylabel("Temperature (F)")
# plt.grid(True)

# plt.savefig("Output/City Latitude Vs. Temperature.png")
# plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# plt.scatter(weather_data_df["Lat"], weather_data_df["Humidity"], marker="o", s=12)
# plt.title("City Latitude Vs. Humidity")
# plt.xlabel("Latitude")
# plt.ylabel("Humidity (%)")
# plt.grid(True)

# plt.savefig("Output/City Latitude Vs. Humidity.png")
# plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# plt.scatter(weather_data_df["Lat"], weather_data_df["Clouds"], marker="o", s=12)
# plt.title("City Latitude Vs. Cloudiness")
# plt.xlabel("Latitude")
# plt.ylabel("Cloudiness (%)")
# plt.grid(True)

# plt.savefig("Output/City Latitude Vs. Cloudiness.png")
# plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# plt.scatter(weather_data_df["Lat"], weather_data_df["Wind MPH"], marker="o", s=12)
# plt.title("City Latitude Vs. Wind Speed")
# plt.xlabel("Latitude")
# plt.ylabel("Wind Speed (mph)")
# plt.grid(True)

# plt.savefig("Output/City Latitude Vs. Wind Speed.png")
# plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Seperate Northern and Southern Hemisphere Data
# north_hemi_df = weather_data_df.loc[weather_data_df["Lat"] > 0]
# south_hemi_df = weather_data_df.loc[weather_data_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# temp=north_hemi_df["Temperature (F)"]
# lat=north_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(temp, lat)
# regress_values = temp * slope + intercept

# plt.scatter(temp, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Northern Hemishpere Cities Temperature Vs. Latitude")
# plt.xlabel("Temperature (F)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(-5,10),size=12)
# plt.savefig("Output/Northern Hemishpere Cities Temperature Vs. Latitude.png")
# plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# temp=south_hemi_df["Temperature (F)"]
# lat=south_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(temp, lat)
# regress_values = temp * slope + intercept

# plt.scatter(temp, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Southern Hemishpere Cities Temperature Vs. Latitude")
# plt.xlabel("Temperature (F)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(75,-50),size=12)
# plt.savefig("Output/Southern Hemishpere Cities Temperature Vs. Latitude.png")
# plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# humid=north_hemi_df["Humidity (%)"]
# lat=north_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(humid, lat)
# regress_values = humid * slope + intercept

# plt.scatter(humid, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Northern Hemishpere Cities Humidity Vs. Latitude")
# plt.xlabel("Humidity (%)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(5,75),size=12)
# plt.savefig("Output/Northern Hemishpere Cities Humidity Vs. Latitude.png")
# plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# humid=south_hemi_df["Humidity (%)"]
# lat=south_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(humid, lat)
# regress_values = humid * slope + intercept

# plt.scatter(humid, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Southern Hemishpere Cities Humidity Vs. Latitude")
# plt.xlabel("Humidity (%)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(25,-50),size=12)
# plt.savefig("Output/Southern Hemishpere Cities Humidity Vs. Latitude.png")
# plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# cloud=north_hemi_df["Cloudiness (%)"]
# lat=north_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(cloud, lat)
# regress_values = cloud * slope + intercept

# plt.scatter(cloud, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Northern Hemishpere Cities Cloudiness Vs. Latitude")
# plt.xlabel("Cloudiness (%)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(20,75),size=12)
# plt.savefig("Output/Northern Hemishpere Cities Cloudiness Vs. Latitude.png")
# plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# cloud=south_hemi_df["Cloudiness (%)"]
# lat=south_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(cloud, lat)
# regress_values = cloud * slope + intercept

# plt.scatter(cloud, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Southern Hemishpere Cities Cloudiness Vs. Latitude")
# plt.xlabel("Cloudiness (%)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(25,-50),size=12)
# plt.savefig("Output/Southern Hemishpere Cities Cloudiness Vs. Latitude.png")
# plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# wind=north_hemi_df["Wind Speed (mph)"]
# lat=north_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(wind, lat)
# regress_values = wind * slope + intercept

# plt.scatter(wind, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Northern Hemishpere Cities Wind Speed Vs. Latitude")
# plt.xlabel("Wind Speed (mph)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(20,75),size=12)
# plt.savefig("Output/Northern Hemishpere Cities Wind Speed Vs. Latitude.png")
# plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# wind=south_hemi_df["Wind Speed (mph)"]
# lat=south_hemi_df["Latitude"]

# slope, intercept, r_value, p_value, stderr = st.linregress(wind, lat)
# regress_values = wind * slope + intercept

# plt.scatter(wind, lat, marker="o", s=12)

# print(f"The r-value is: {r-value})
      
# plt.title("Southern Hemishpere Cities Wind Speed Vs. Latitude")
# plt.xlabel("Wind Speed (mph)")
# plt.ylabel("Latitude")
# plt.grid(True)
      
# plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}",(20,-50),size=12)
# plt.savefig("Output/Southern Hemishpere Cities Wind Speed Vs. Latitude.png")
# plt.show()
